# %%
# this sets up the virtual environment if gdrive doesn't contain the repo clone
# it by setting the the if to true and modifie the path as you wish
#@title Default title text
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
import os
# !pip install -q xlrd
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/ADL4CV')
#!ls
if False:
  from getpass import getpass
  user = getpass('GitHub user')
  password = getpass('GitHub password')
  os.environ['GitHub_AUTH'] = user + ':' + password
  # !git clone https://$GitHub_AUTH@github.com/Cram13/ADL4CV_Project.git
os.chdir('ADL4CV_Project')
# !git pull origin master
# !pip install -I pillow==5.1.0
# !pip3 install torch torchvision
# !pip3 install tensorboardX
#!pip install PIL
#!pip install image
#import PIL.image
# Out:
# --2018-12-03 15:11:14--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.72.145.109, 52.87.35.92, 54.165.51.142, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.72.145.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5363700 (5.1M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.1’
#
# ngrok-stable-linux- 100%[===================>]   5.11M  7.86MB/s    in 0.7s
#
# 2018-12-03 15:11:15 (7.86 MB/s) - ‘ngrok-stable-linux-amd64.zip.1’ saved [5363700/5363700]
#
# Archive:  ngrok-stable-linux-amd64.zip
# replace ngrok? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ngrok
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/Cram13/ADL4CV_Project
#  * branch            master     -> FETCH_HEAD
#    4749e7f..0441dba  master     -> origin/master
# Updating 4749e7f..0441dba
# Fast-forward
#  lstm/LSTMLosses.py |  81 +++++++++++++++++++++++++--
#  lstm/LSTMModels.py |   6 +-
#  lstm/lstm_test.py  | 110 -------------------------------------
#  lstm_test.py       | 158 +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  4 files changed, 238 insertions(+), 117 deletions(-)
#  delete mode 100644 lstm/lstm_test.py
#  create mode 100644 lstm_test.py
# Collecting pillow==5.1.0
#   Downloading https://files.pythonhosted.org/packages/5f/4b/8b54ab9d37b93998c81b364557dff9f61972c0f650efa0ceaf470b392740/Pillow-5.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 15.2MB/s
# Installing collected packages: pillow
# Successfully installed pillow-5.1.0
# Collecting torch
#   Downloading https://files.pythonhosted.org/packages/49/0e/e382bcf1a6ae8225f50b99cc26effa2d4cc6d66975ccf3fa9590efcbedce/torch-0.4.1-cp36-cp36m-manylinux1_x86_64.whl (519.5MB)
#     100% |████████████████████████████████| 519.5MB 29kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x5a396000 @  0x7f56284be2a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# Collecting torchvision
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 22.3MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (5.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.6)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Installing collected packages: torch, torchvision
# Successfully installed torch-0.4.1 torchvision-0.2.1
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/b1/d2/e08fe62f3554fbba081e80f6b23128df53b2f74ed4dcde73ec4a84dc53fb/tensorboardX-1.4-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 5.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.14.6)
# Requirement already satisfied: protobuf>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.2.0->tensorboardX) (40.6.2)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-1.4

# %%
#!git checkout origin/master
# !git pull origin master
#!git status
#!git fetch
#!git reset --hard origin/master
# Out:
# From https://github.com/Cram13/ADL4CV_Project
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
#setup options for training
from train_yolo_example import Opt

opt = Opt()
opt.batch_size = 1
opt.num_epoches = 100

# %%
#fire up tensorboard in the background
#todo make path first
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(opt.log_path)
)
get_ipython().system_raw('/content/ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://9c320fb9.ngrok.io

# %%
#!ls
from train_yolo_example import Opt
from train_yolo_example import train
opt = Opt()
opt.batch_size = 1
opt.num_epoches = 100
#opt = get_args()
train(opt)
# Out:
# dataset_utils  log   models	  train_yolo_example.py  Yolo_pytorch
# __init__.py    lstm  __pycache__  yolo
# num epoch:    0
# /content/drive/My Drive/ADL4CV/ADL4CV_Project/yolo/loss.py:45: UserWarning: torch.range is deprecated in favor of torch.arange and will be removed in 0.5. Note that arange generates values in [start; end), not [start; end].
#   lin_x = torch.range(0, width - 1).repeat(height, 1).view(height * width)
# /content/drive/My Drive/ADL4CV/ADL4CV_Project/yolo/loss.py:46: UserWarning: torch.range is deprecated in favor of torch.arange and will be removed in 0.5. Note that arange generates values in [start; end), not [start; end].
#   lin_y = torch.range(0, height - 1).repeat(width, 1).t().contiguous().view(height * width)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:52: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Iteration       0 loss: 274.2896, 	coord_loss:  63.0433, 	conf_loss: 211.2462
# Iteration     100 loss: 223.9295, 	coord_loss:  23.9707, 	conf_loss: 199.9588
# Iteration     200 loss: 305.9178, 	coord_loss: 104.0114, 	conf_loss: 201.9064
# Iteration     300 loss: 234.2789, 	coord_loss:  44.3855, 	conf_loss: 189.8934
# Iteration     400 loss: 186.9295, 	coord_loss:   9.7225, 	conf_loss: 177.2070
# Iteration     500 loss: 198.4230, 	coord_loss:  26.6614, 	conf_loss: 171.7616
# Iteration     600 loss: 206.2270, 	coord_loss:  36.9546, 	conf_loss: 169.2725
# Iteration     700 loss: 169.5835, 	coord_loss:  11.1281, 	conf_loss: 158.4554
# Iteration     800 loss: 166.5538, 	coord_loss:  12.7051, 	conf_loss: 153.8488
# Iteration     900 loss: 161.1393, 	coord_loss:  11.8959, 	conf_loss: 149.2434
# Iteration    1000 loss: 159.3794, 	coord_loss:  16.8435, 	conf_loss: 142.5359
# Iteration    1100 loss: 135.3937, 	coord_loss:   1.7249, 	conf_loss: 133.6688
# Iteration    1200 loss: 149.7836, 	coord_loss:  19.4174, 	conf_loss: 130.3663
# Iteration    1300 loss: 167.1649, 	coord_loss:  38.3767, 	conf_loss: 128.7882
# Iteration    1400 loss: 123.4333, 	coord_loss:   3.1113, 	conf_loss: 120.3220
# Iteration    1500 loss: 118.3493, 	coord_loss:   1.6621, 	conf_loss: 116.6872
# Iteration    1600 loss: 115.4233, 	coord_loss:   4.6512, 	conf_loss: 110.7721
# Iteration    1700 loss: 111.8265, 	coord_loss:   5.2924, 	conf_loss: 106.5341
# Iteration    1800 loss: 104.6587, 	coord_loss:   3.7477, 	conf_loss: 100.9110
# Iteration    1900 loss: 118.0379, 	coord_loss:  20.8413, 	conf_loss:  97.1966
# Iteration    2000 loss: 102.4868, 	coord_loss:   7.5414, 	conf_loss:  94.9454
# Iteration    2100 loss:  95.0618, 	coord_loss:   3.2016, 	conf_loss:  91.8602
# Iteration    2200 loss:  91.5700, 	coord_loss:   4.9317, 	conf_loss:  86.6383
# Iteration    2300 loss:  90.3262, 	coord_loss:   5.5947, 	conf_loss:  84.7315
# Iteration    2400 loss:  84.1719, 	coord_loss:   4.8995, 	conf_loss:  79.2724
# Iteration    2500 loss:  89.1693, 	coord_loss:  12.2759, 	conf_loss:  76.8933
# Iteration    2600 loss:  83.2346, 	coord_loss:   7.6091, 	conf_loss:  75.6255
# Iteration    2700 loss:  73.8255, 	coord_loss:   2.4792, 	conf_loss:  71.3463
# Iteration    2800 loss:  83.3228, 	coord_loss:  14.5628, 	conf_loss:  68.7600
# Iteration    2900 loss:  68.7062, 	coord_loss:   3.0270, 	conf_loss:  65.6792
# Iteration    3000 loss:  66.4978, 	coord_loss:   2.0732, 	conf_loss:  64.4245
# Iteration    3100 loss:  71.3919, 	coord_loss:  11.9982, 	conf_loss:  59.3937
# Iteration    3200 loss:  64.4347, 	coord_loss:   5.7396, 	conf_loss:  58.6950
# Iteration    3300 loss:  64.5122, 	coord_loss:   7.0969, 	conf_loss:  57.4153
# Iteration    3400 loss:  56.7315, 	coord_loss:   2.7335, 	conf_loss:  53.9980
# Iteration    3500 loss:  55.1702, 	coord_loss:   3.7937, 	conf_loss:  51.3765
# Iteration    3600 loss:  52.8786, 	coord_loss:   3.7005, 	conf_loss:  49.1780
# Iteration    3700 loss:  50.9810, 	coord_loss:   1.9287, 	conf_loss:  49.0524
# Iteration    3800 loss:  50.5488, 	coord_loss:   4.6796, 	conf_loss:  45.8692
# Iteration    3900 loss:  43.0542, 	coord_loss:   1.8132, 	conf_loss:  41.2410
# Iteration    4000 loss:  42.5875, 	coord_loss:   2.3884, 	conf_loss:  40.1991
# Iteration    4100 loss:  43.2295, 	coord_loss:   2.6257, 	conf_loss:  40.6038
# Iteration    4200 loss:  40.0308, 	coord_loss:   3.1453, 	conf_loss:  36.8855
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# load_time: nan
# network_time: nan
# loss_time: nan
# optim_time: nan
# log_time: nan
# 47.245731353759766  8.67007827758789   38.57565689086914
# num epoch:    1
# Iteration    4252 loss:  39.7166, 	coord_loss:   1.5916, 	conf_loss:  38.1250
# Iteration    4352 loss:  49.8310, 	coord_loss:  14.0598, 	conf_loss:  35.7712
# Iteration    4452 loss:  42.4703, 	coord_loss:   8.3265, 	conf_loss:  34.1437
# Iteration    4552 loss:  34.2639, 	coord_loss:   1.3612, 	conf_loss:  32.9027
# Iteration    4652 loss:  32.7287, 	coord_loss:   2.1904, 	conf_loss:  30.5383
# Iteration    4752 loss:  34.0171, 	coord_loss:   3.2889, 	conf_loss:  30.7282
# Iteration    4852 loss:  35.4652, 	coord_loss:   6.2691, 	conf_loss:  29.1961
# Iteration    4952 loss:  33.2843, 	coord_loss:   5.8266, 	conf_loss:  27.4578
# Iteration    5052 loss:  32.4084, 	coord_loss:   5.3437, 	conf_loss:  27.0647
# Iteration    5152 loss:  32.4803, 	coord_loss:   2.3771, 	conf_loss:  30.1032
# Iteration    5252 loss:  28.7773, 	coord_loss:   2.6172, 	conf_loss:  26.1601
# Iteration    5352 loss:  29.1696, 	coord_loss:   2.5912, 	conf_loss:  26.5784
# Iteration    5452 loss:  30.3158, 	coord_loss:   7.4644, 	conf_loss:  22.8514
# Iteration    5552 loss:  27.1455, 	coord_loss:   3.4845, 	conf_loss:  23.6610
# Iteration    5652 loss:  24.1186, 	coord_loss:   2.0240, 	conf_loss:  22.0945
# Iteration    5752 loss:  25.4473, 	coord_loss:   4.4419, 	conf_loss:  21.0055
# Iteration    5852 loss:  26.4001, 	coord_loss:   2.7821, 	conf_loss:  23.6180
# Iteration    5952 loss:  20.5751, 	coord_loss:   1.5242, 	conf_loss:  19.0509
# Iteration    6052 loss:  21.3064, 	coord_loss:   2.1707, 	conf_loss:  19.1357
# Iteration    6152 loss:  20.2242, 	coord_loss:   1.7024, 	conf_loss:  18.5218
# Iteration    6252 loss:  20.7508, 	coord_loss:   1.9639, 	conf_loss:  18.7869
# Iteration    6352 loss:  18.8174, 	coord_loss:   2.7013, 	conf_loss:  16.1161
# Iteration    6452 loss:  17.0756, 	coord_loss:   1.6181, 	conf_loss:  15.4575
# Iteration    6552 loss:  16.0076, 	coord_loss:   1.1692, 	conf_loss:  14.8384
# Iteration    6652 loss:  18.1861, 	coord_loss:   1.8049, 	conf_loss:  16.3812
# Iteration    6752 loss:  15.0213, 	coord_loss:   1.2001, 	conf_loss:  13.8212
# Iteration    6852 loss:  14.4827, 	coord_loss:   1.2774, 	conf_loss:  13.2053
# Iteration    6952 loss:  14.5204, 	coord_loss:   1.6714, 	conf_loss:  12.8490
# Iteration    7052 loss:  15.3728, 	coord_loss:   2.4145, 	conf_loss:  12.9583
# Iteration    7152 loss:  20.1078, 	coord_loss:   5.9541, 	conf_loss:  14.1537
# Iteration    7252 loss:  13.1592, 	coord_loss:   1.3482, 	conf_loss:  11.8110
# Iteration    7352 loss:  14.8965, 	coord_loss:   3.3758, 	conf_loss:  11.5207
# Iteration    7452 loss:  15.9449, 	coord_loss:   3.0404, 	conf_loss:  12.9045
# Iteration    7552 loss:  11.7449, 	coord_loss:   1.7389, 	conf_loss:  10.0059
# Iteration    7652 loss:  17.3088, 	coord_loss:   5.0515, 	conf_loss:  12.2573
# Iteration    7752 loss:  11.6218, 	coord_loss:   1.8300, 	conf_loss:   9.7918
# Iteration    7852 loss:  10.9906, 	coord_loss:   1.6202, 	conf_loss:   9.3705
# Iteration    7952 loss:  11.0212, 	coord_loss:   1.8647, 	conf_loss:   9.1565
# Iteration    8052 loss:  11.8506, 	coord_loss:   1.6365, 	conf_loss:  10.2140
# Iteration    8152 loss:  10.7280, 	coord_loss:   2.2902, 	conf_loss:   8.4378
# Iteration    8252 loss:   9.0413, 	coord_loss:   1.2070, 	conf_loss:   7.8343
# Iteration    8352 loss:  10.1755, 	coord_loss:   2.6712, 	conf_loss:   7.5043
# Iteration    8452 loss:  12.2966, 	coord_loss:   4.4841, 	conf_loss:   7.8125
# load_time: nan
# network_time: nan
# loss_time: nan
# optim_time: nan
# log_time: nan
# 13.824527740478516  5.595722198486328   8.228789329528809
# num epoch:    2
# Iteration    8504 loss:   9.5576, 	coord_loss:   2.0119, 	conf_loss:   7.5457
# Iteration    8604 loss:  12.7749, 	coord_loss:   3.6949, 	conf_loss:   9.0799
# Iteration    8704 loss:  12.6593, 	coord_loss:   4.4330, 	conf_loss:   8.2263
# Iteration    8804 loss:  13.0918, 	coord_loss:   5.0590, 	conf_loss:   8.0328
# Iteration    8904 loss:   8.1705, 	coord_loss:   1.3567, 	conf_loss:   6.8138
# Iteration    9004 loss:   6.8686, 	coord_loss:   0.9148, 	conf_loss:   5.9537
# Iteration    9104 loss:   9.3617, 	coord_loss:   1.2722, 	conf_loss:   8.0895
# Iteration    9204 loss:   8.7776, 	coord_loss:   1.4315, 	conf_loss:   7.3461
# Iteration    9304 loss:   9.8750, 	coord_loss:   4.0640, 	conf_loss:   5.8110
# Iteration    9404 loss:   7.0781, 	coord_loss:   1.4256, 	conf_loss:   5.6526
# Iteration    9504 loss:  10.5808, 	coord_loss:   4.7552, 	conf_loss:   5.8256
# Iteration    9604 loss:   6.0990, 	coord_loss:   0.8996, 	conf_loss:   5.1994
# Iteration    9704 loss:   5.7987, 	coord_loss:   0.9650, 	conf_loss:   4.8337
# Iteration    9804 loss:   7.9196, 	coord_loss:   1.1563, 	conf_loss:   6.7633
# Iteration    9904 loss:  11.5510, 	coord_loss:   5.3225, 	conf_loss:   6.2285
# Iteration   10004 loss:   5.5140, 	coord_loss:   1.2752, 	conf_loss:   4.2388
# Iteration   10104 loss:   5.7334, 	coord_loss:   1.4189, 	conf_loss:   4.3145
# Iteration   10204 loss:   6.1944, 	coord_loss:   1.4280, 	conf_loss:   4.7664
# Iteration   10304 loss:   6.2969, 	coord_loss:   1.6395, 	conf_loss:   4.6574
# Iteration   10404 loss:   9.3339, 	coord_loss:   3.8566, 	conf_loss:   5.4773
# Iteration   10504 loss:   5.4674, 	coord_loss:   0.8600, 	conf_loss:   4.6074
# Iteration   10604 loss:   8.5068, 	coord_loss:   1.2800, 	conf_loss:   7.2268
# Iteration   10704 loss:   6.6613, 	coord_loss:   1.5032, 	conf_loss:   5.1582
# Iteration   10804 loss:   7.3819, 	coord_loss:   3.4536, 	conf_loss:   3.9283
# Iteration   10904 loss:   6.5938, 	coord_loss:   2.8913, 	conf_loss:   3.7024
# Iteration   11004 loss:   7.2882, 	coord_loss:   3.6457, 	conf_loss:   3.6425
# Iteration   11104 loss:   4.7907, 	coord_loss:   1.6157, 	conf_loss:   3.1750
# Iteration   11204 loss:   4.9535, 	coord_loss:   1.4826, 	conf_loss:   3.4709
# Iteration   11304 loss:   7.0126, 	coord_loss:   2.7232, 	conf_loss:   4.2894
# Iteration   11404 loss:   3.0620, 	coord_loss:   0.5243, 	conf_loss:   2.5377
# Iteration   11504 loss:   5.1652, 	coord_loss:   1.1190, 	conf_loss:   4.0462
# Iteration   11604 loss:   8.2559, 	coord_loss:   4.2887, 	conf_loss:   3.9673
# Iteration   11704 loss:   3.3188, 	coord_loss:   0.7501, 	conf_loss:   2.5687
# Iteration   11804 loss:   3.4767, 	coord_loss:   1.0601, 	conf_loss:   2.4166
# Iteration   11904 loss:   7.5114, 	coord_loss:   0.6231, 	conf_loss:   6.8883
# Iteration   12004 loss:   3.3260, 	coord_loss:   0.7166, 	conf_loss:   2.6094
# Iteration   12104 loss:   7.8393, 	coord_loss:   2.2857, 	conf_loss:   5.5536
# Iteration   12204 loss:   5.8002, 	coord_loss:   0.7259, 	conf_loss:   5.0743
# Iteration   12304 loss:   6.6041, 	coord_loss:   1.3714, 	conf_loss:   5.2327
# Iteration   12404 loss:   6.4091, 	coord_loss:   1.9065, 	conf_loss:   4.5026
# Iteration   12504 loss:   7.4269, 	coord_loss:   3.2436, 	conf_loss:   4.1833
# Iteration   12604 loss:   2.4299, 	coord_loss:   0.6689, 	conf_loss:   1.7610
# Iteration   12704 loss:   4.1208, 	coord_loss:   1.4899, 	conf_loss:   2.6309
# load_time: nan
# network_time: nan
# loss_time: nan
# optim_time: nan
# log_time: nan
# 8.56411361694336  5.100515365600586   3.463596820831299
# num epoch:    3
# Iteration   12756 loss:   4.6388, 	coord_loss:   1.1545, 	conf_loss:   3.4844
# Iteration   12856 loss:   7.2885, 	coord_loss:   3.9079, 	conf_loss:   3.3806
# Iteration   12956 loss:   5.1240, 	coord_loss:   2.1329, 	conf_loss:   2.9910
# Iteration   13056 loss:   3.2048, 	coord_loss:   0.8156, 	conf_loss:   2.3892
# Iteration   13156 loss:   2.6052, 	coord_loss:   0.7423, 	conf_loss:   1.8629
# Iteration   13256 loss:   6.7135, 	coord_loss:   3.9270, 	conf_loss:   2.7866
# Iteration   13356 loss:   5.5191, 	coord_loss:   3.0872, 	conf_loss:   2.4318
# Iteration   13456 loss:   2.2391, 	coord_loss:   0.8095, 	conf_loss:   1.4296
# Iteration   13556 loss:   3.9484, 	coord_loss:   1.8119, 	conf_loss:   2.1365
# Iteration   13656 loss:   2.9899, 	coord_loss:   1.6149, 	conf_loss:   1.3750
# Iteration   13756 loss:   2.8252, 	coord_loss:   0.8908, 	conf_loss:   1.9344
# Iteration   13856 loss:   4.4218, 	coord_loss:   2.8657, 	conf_loss:   1.5561
# Iteration   13956 loss:   5.0889, 	coord_loss:   2.9122, 	conf_loss:   2.1767
# Iteration   14056 loss:   3.3497, 	coord_loss:   1.0164, 	conf_loss:   2.3332
# Iteration   14156 loss:   3.6905, 	coord_loss:   2.1921, 	conf_loss:   1.4984
# Iteration   14256 loss:   2.8247, 	coord_loss:   1.1443, 	conf_loss:   1.6804
# Iteration   14356 loss:   2.9334, 	coord_loss:   0.9505, 	conf_loss:   1.9829
# Iteration   14456 loss:   3.0098, 	coord_loss:   1.4342, 	conf_loss:   1.5756
# Iteration   14556 loss:   5.2949, 	coord_loss:   1.5666, 	conf_loss:   3.7283
# Iteration   14656 loss:   4.4003, 	coord_loss:   1.9810, 	conf_loss:   2.4193
# Iteration   14756 loss:   2.8074, 	coord_loss:   1.5402, 	conf_loss:   1.2672
# Iteration   14856 loss:   2.9721, 	coord_loss:   1.0633, 	conf_loss:   1.9088
# Iteration   14956 loss:   3.3661, 	coord_loss:   2.0128, 	conf_loss:   1.3534
# Iteration   15056 loss:   3.0690, 	coord_loss:   1.6380, 	conf_loss:   1.4310
# Iteration   15156 loss:   1.6635, 	coord_loss:   0.8030, 	conf_loss:   0.8604
# Iteration   15256 loss:   2.7473, 	coord_loss:   1.6111, 	conf_loss:   1.1362
# Iteration   15356 loss:   1.6184, 	coord_loss:   0.6570, 	conf_loss:   0.9614
# Iteration   15456 loss:   3.8373, 	coord_loss:   2.3196, 	conf_loss:   1.5176
# Iteration   15556 loss:   3.2273, 	coord_loss:   0.9368, 	conf_loss:   2.2905
# Iteration   15656 loss:   3.1089, 	coord_loss:   1.4287, 	conf_loss:   1.6802
# Iteration   15756 loss:   2.9490, 	coord_loss:   1.2223, 	conf_loss:   1.7266
# Iteration   15856 loss:   1.9032, 	coord_loss:   0.9370, 	conf_loss:   0.9662
# Iteration   15956 loss:   3.5174, 	coord_loss:   1.4561, 	conf_loss:   2.0613
# Iteration   16056 loss:   2.0523, 	coord_loss:   0.9302, 	conf_loss:   1.1221
# Iteration   16156 loss:   1.2879, 	coord_loss:   0.6556, 	conf_loss:   0.6323
# Iteration   16256 loss:   2.8669, 	coord_loss:   1.3188, 	conf_loss:   1.5481
# Iteration   16356 loss:   4.4874, 	coord_loss:   1.2605, 	conf_loss:   3.2270
# Iteration   16456 loss:   4.2886, 	coord_loss:   1.3580, 	conf_loss:   2.9305
# Iteration   16556 loss:   2.1835, 	coord_loss:   1.1396, 	conf_loss:   1.0439
# Iteration   16656 loss:   1.8747, 	coord_loss:   0.6543, 	conf_loss:   1.2205
# Iteration   16756 loss:   6.2365, 	coord_loss:   1.2363, 	conf_loss:   5.0002
# Iteration   16856 loss:   2.9147, 	coord_loss:   0.9270, 	conf_loss:   1.9877
# Iteration   16956 loss:   1.2462, 	coord_loss:   0.4602, 	conf_loss:   0.7860
# load_time: nan
# network_time: nan
# loss_time: nan
# optim_time: nan
# log_time: nan
# 7.67522668838501  4.970760822296143   2.704461097717285
# num epoch:    4
# Iteration   17008 loss:   2.0646, 	coord_loss:   1.2960, 	conf_loss:   0.7687
# Iteration   17108 loss:   1.5197, 	coord_loss:   0.8244, 	conf_loss:   0.6953
# Iteration   17208 loss:   2.1784, 	coord_loss:   0.8035, 	conf_loss:   1.3749
# Iteration   17308 loss:   0.7193, 	coord_loss:   0.1972, 	conf_loss:   0.5221
# Iteration   17408 loss:   3.6839, 	coord_loss:   2.4717, 	conf_loss:   1.2121
# Iteration   17508 loss:   1.5021, 	coord_loss:   0.6808, 	conf_loss:   0.8212
# Iteration   17608 loss:   3.0341, 	coord_loss:   2.0486, 	conf_loss:   0.9855
# Iteration   17708 loss:   1.5321, 	coord_loss:   0.6919, 	conf_loss:   0.8402
# Iteration   17808 loss:   2.0826, 	coord_loss:   0.8495, 	conf_loss:   1.2331
# Iteration   17908 loss:   2.0867, 	coord_loss:   1.0604, 	conf_loss:   1.0263
# Iteration   18008 loss:   2.7366, 	coord_loss:   1.4386, 	conf_loss:   1.2980
# Iteration   18108 loss:   1.5841, 	coord_loss:   0.4832, 	conf_loss:   1.1009
# Iteration   18208 loss:   1.7603, 	coord_loss:   0.9512, 	conf_loss:   0.8091
# Iteration   18308 loss:   2.9793, 	coord_loss:   1.0255, 	conf_loss:   1.9537
# Iteration   18408 loss:   1.3802, 	coord_loss:   0.5757, 	conf_loss:   0.8045
# Iteration   18508 loss:   5.9263, 	coord_loss:   1.7108, 	conf_loss:   4.2155
# Iteration   18608 loss:   0.9147, 	coord_loss:   0.2699, 	conf_loss:   0.6447
# Iteration   18708 loss:   3.3484, 	coord_loss:   2.0593, 	conf_loss:   1.2891
# Iteration   18808 loss:   1.4158, 	coord_loss:   0.2496, 	conf_loss:   1.1663
# Iteration   18908 loss:   2.1172, 	coord_loss:   1.4428, 	conf_loss:   0.6744
# Iteration   19008 loss:   1.4524, 	coord_loss:   0.6981, 	conf_loss:   0.7543
# Iteration   19108 loss:   1.7265, 	coord_loss:   0.8392, 	conf_loss:   0.8874
# Iteration   19208 loss:   1.8511, 	coord_loss:   1.1684, 	conf_loss:   0.6826
# Iteration   19308 loss:   1.6161, 	coord_loss:   0.8182, 	conf_loss:   0.7979
# Iteration   19408 loss:   0.4904, 	coord_loss:   0.1356, 	conf_loss:   0.3548
# Iteration   19508 loss:   4.9566, 	coord_loss:   2.0110, 	conf_loss:   2.9456
# Iteration   19608 loss:   0.9593, 	coord_loss:   0.4950, 	conf_loss:   0.4643
# Iteration   19708 loss:   1.5006, 	coord_loss:   0.7072, 	conf_loss:   0.7934
# Iteration   19808 loss:   0.7987, 	coord_loss:   0.2953, 	conf_loss:   0.5034
# Iteration   19908 loss:   5.7651, 	coord_loss:   3.9006, 	conf_loss:   1.8646
# Iteration   20008 loss:   2.9502, 	coord_loss:   0.9456, 	conf_loss:   2.0046
# Iteration   20108 loss:   1.5119, 	coord_loss:   0.6182, 	conf_loss:   0.8937
# Iteration   20208 loss:   2.3229, 	coord_loss:   1.3871, 	conf_loss:   0.9358
# Iteration   20308 loss:   1.1719, 	coord_loss:   0.5576, 	conf_loss:   0.6143
# Iteration   20408 loss:   1.5833, 	coord_loss:   1.0706, 	conf_loss:   0.5128
# Iteration   20508 loss:   0.9718, 	coord_loss:   0.5231, 	conf_loss:   0.4487
# Iteration   20608 loss:   1.0398, 	coord_loss:   0.6544, 	conf_loss:   0.3854
# Iteration   20708 loss:   2.4962, 	coord_loss:   1.4583, 	conf_loss:   1.0378
# Iteration   20808 loss:   1.6157, 	coord_loss:   1.2064, 	conf_loss:   0.4093
# Iteration   20908 loss:   1.7758, 	coord_loss:   0.8982, 	conf_loss:   0.8776
# Iteration   21008 loss:   2.9643, 	coord_loss:   1.2722, 	conf_loss:   1.6921
# Iteration   21108 loss:   3.8786, 	coord_loss:   0.8406, 	conf_loss:   3.0381
# Iteration   21208 loss:   0.6078, 	coord_loss:   0.1515, 	conf_loss:   0.4563
# load_time: nan
# network_time: nan
# loss_time: nan
# optim_time: nan
# log_time: nan
# 7.252602577209473  4.7130351066589355   2.5395658016204834
# num epoch:    5
# Iteration   21260 loss:   1.2111, 	coord_loss:   0.4660, 	conf_loss:   0.7451
# Iteration   21360 loss:   1.2327, 	coord_loss:   0.2059, 	conf_loss:   1.0268
# Iteration   21460 loss:   2.6261, 	coord_loss:   1.8312, 	conf_loss:   0.7949
# Iteration   21560 loss:   0.7590, 	coord_loss:   0.2361, 	conf_loss:   0.5229
# Iteration   21660 loss:   1.7746, 	coord_loss:   1.1180, 	conf_loss:   0.6567
# Iteration   21760 loss:   1.0372, 	coord_loss:   0.5847, 	conf_loss:   0.4525
# Iteration   21860 loss:   0.9224, 	coord_loss:   0.3019, 	conf_loss:   0.6205
# Iteration   21960 loss:   6.1710, 	coord_loss:   1.1867, 	conf_loss:   4.9843
# Iteration   22060 loss:   0.6996, 	coord_loss:   0.3123, 	conf_loss:   0.3873
# Iteration   22160 loss:   0.6248, 	coord_loss:   0.3770, 	conf_loss:   0.2478
# Iteration   22260 loss:   1.9908, 	coord_loss:   1.4212, 	conf_loss:   0.5696
# Iteration   22360 loss:   0.4375, 	coord_loss:   0.2120, 	conf_loss:   0.2255
# Iteration   22460 loss:   1.3116, 	coord_loss:   0.4676, 	conf_loss:   0.8439
# Iteration   22560 loss:   2.2951, 	coord_loss:   1.2999, 	conf_loss:   0.9951
# Iteration   22660 loss:   0.8443, 	coord_loss:   0.4521, 	conf_loss:   0.3921
# Iteration   22760 loss:   1.1893, 	coord_loss:   0.5671, 	conf_loss:   0.6221
# Iteration   22860 loss:   0.8590, 	coord_loss:   0.3620, 	conf_loss:   0.4970
# Iteration   22960 loss:   3.5881, 	coord_loss:   1.6713, 	conf_loss:   1.9168
# Iteration   23060 loss:   1.2541, 	coord_loss:   0.7854, 	conf_loss:   0.4687
# Iteration   23160 loss:   2.1010, 	coord_loss:   0.5916, 	conf_loss:   1.5093
# Iteration   23260 loss:   0.6665, 	coord_loss:   0.3802, 	conf_loss:   0.2863
# Iteration   23360 loss:   1.4646, 	coord_loss:   1.0643, 	conf_loss:   0.4002
# Iteration   23460 loss:   1.8219, 	coord_loss:   1.2054, 	conf_loss:   0.6165
# Iteration   23560 loss:   3.9636, 	coord_loss:   2.3854, 	conf_loss:   1.5782
# Iteration   23660 loss:   2.9027, 	coord_loss:   1.3740, 	conf_loss:   1.5287
# Iteration   23760 loss:   0.8288, 	coord_loss:   0.1688, 	conf_loss:   0.6601
# Iteration   23860 loss:   1.9262, 	coord_loss:   1.2519, 	conf_loss:   0.6743
# Iteration   23960 loss:   0.8682, 	coord_loss:   0.4301, 	conf_loss:   0.4381
# Iteration   24060 loss:   2.6794, 	coord_loss:   1.7945, 	conf_loss:   0.8849
# Iteration   24160 loss:   1.1685, 	coord_loss:   0.4565, 	conf_loss:   0.7120
# Iteration   24260 loss:   0.4376, 	coord_loss:   0.2778, 	conf_loss:   0.1599
# Iteration   24360 loss:   1.4881, 	coord_loss:   0.9530, 	conf_loss:   0.5351
# Iteration   24460 loss:   1.5217, 	coord_loss:   0.8763, 	conf_loss:   0.6454
# Iteration   24560 loss:   0.4592, 	coord_loss:   0.1976, 	conf_loss:   0.2616
# Iteration   24660 loss:   0.5790, 	coord_loss:   0.2498, 	conf_loss:   0.3292

# %%
import time
for i in range(3600):
  time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-6f97098fd12e> in <module>()
#       1 import time
#       2 for i in range(3600):
# ----> 3   time.sleep(10)
#
# KeyboardInterrupt:
